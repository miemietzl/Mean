# %% [markdown]
# <a href="https://colab.research.google.com/github/miemietzl/Mean/blob/master/image_detection_from_evacuation_maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebooks contains the code for detecting rooms, doors and map data from public available escape plan (Fluchtplan)

# %% [markdown]
# See example below, containing multiple offices, meeting rooms, stairways, floors and exits.

# %% [markdown]
# ![fluchtplan_2019.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# For the classification, we assume the following
#
#
# 1.   Small room (consists of one door)
# 2.   Big room (consists of two doors)
# 3.   Staircase
# 4.   Emergency exits

# %%
#include repositories
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a4637bbefc43> in <module>
# ----> 1 python --version
#
# NameError: name 'python' is not defined
